# %% [markdown]
# <a href="https://colab.research.google.com/github/LivesayMe/cse480-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Info

# %% [markdown]
# Hunter Livesay
# CSE480 Computational Theory
# Brother Neff
# Final Grade Claim

# %% [markdown]
# # Claimed Grade

# %% [markdown]
# I am claiming an A.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Evidences of B Grade

# %% [markdown]
# ## NP Completeness Ponder and Prove

# %% [markdown]
# [16.7.2.1](https://colab.research.google.com/github/LivesayMe/cse480-notebooks/blob/master/11_2_Ponder_and_Prove_NP_Completeness.ipynb#scrollTo=S7e2hO0ndg5C)

# %% [markdown]
# This isn't a particularly prfound realization, but I realized that this question and the last question 16.7.2.12 where really asking the same thing.

# %% [markdown]
# [16.7.2.9](https://colab.research.google.com/github/LivesayMe/cse480-notebooks/blob/master/11_2_Ponder_and_Prove_NP_Completeness.ipynb#scrollTo=S7e2hO0ndg5C)
#
# While the structure of the proof was wrong after much trial and error I created a reduction proof from HalfClique to SAT. I realize that the question's hint suggests reducing HalfClique to Clique, but I wanted to deepen my understanding of SAT so I chose the harder conversion instead.

# %% [markdown]
# ## PCP Solving

# %% [markdown]
# [15.2.3.4](https://colab.research.google.com/github/LivesayMe/cse480-notebooks/blob/master/10_2_Ponder_and_Prove_the_Post_Correspondence_Problem.ipynb#scrollTo=q93Y92NjEuOW)
#
# In this exercise I decided to try and show that the unary PCP can be reduced to finding the solutions to a linear equation.

# %% [markdown]
# ## Binary Decision Diagrams

# %% [markdown]
# [Problem 1](https://colab.research.google.com/github/LivesayMe/cse480-notebooks/blob/master/12_1_Ponder_and_Prove_Binary_Decision_Diagrams.ipynb#scrollTo=4NApzKhgHFbw)
#
# I didn't go especially above and beyond with BDD's, but I felt that I developed a deep understanding of what lt2 and gt2 are doing that makes them work when lt1 and gt1 don't

# %% [markdown]
# ## Anecdotal Proof

# %% [markdown]
# # Evidences of Above and Beyond

# %% [markdown]
# ## Books

# %% [markdown]
# ### The Annotated Turing

# %% [markdown]
# In the last 3 weeks of the semester I have started reading "The Anotated Turing" by Charles Petzod. Below is a screenshot of my phone of where I'm currently at:

# %% [markdown]
# ![Screenshot_20210405-101509.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Logicomix

# %% [markdown]
# I also acquired the book Logicomix by Apostolos Doxiadis and Christos Papadimitriou. I plan to read it after finishing "The Annotated Turing"

# %% [markdown]
# ## Programming in the Lambda Calculus

# %% [markdown]
# [Link to Colab Notebook](https://colab.research.google.com/drive/1ZEs_AO-2LE5qcA4Ygp54kaikCVqD9BSO#scrollTo=B7eWFvUxvNgQ)
#
# In order to better understand the Lambda Calculus and especially how recursion and the y combinator works I set out to create a lambda function that accepts a list of numbers and returns a list of numbers sorted. Unfortuantly I wasn't able to fully finish this project, but I made considerable progress.
# In total I made function that could do the following:
# * All arithmetic operations excluding division
# * All boolean comparisons
# * Lists (This was the majority of the work)
# * Recursive functions
#
# My plan to continue it is to research how clojure does sorting. As I was starting to write the actualy sorting function I got stuck due to my procedural programming mindset.

# %% [markdown]
# ## Teaching NP Completeness and the PCP

# %% [markdown]
# I've developed somewhat of a reputation for always talking about math. In order to get proof of this I decided to ask the person I talk about math the most to write down what she remembers form everything I've said this semester.

# %% [markdown]
# *Some of the principles that Hunter talkted to me was about Pumping Lemma theorem and how it proves whether or not a language was regular. We also talked a lot about np complete problems, one example being finding the prime factorizations of a number.* - Anne Harley

# %% [markdown]
# Unfortuantly it seems like she forgot our discussions about SAT, PCP, and the Lambda Calculus but at least she remembered something!
#
# I recognize I don't have proof of teaching more people, but my roomates, Anne's roomates, my siblings all have a much deeper understanding of computational theory and understand why it is worth studying.

# %% [markdown]
# # Final Thoughts

# %% [markdown]
# Coming into this class I wanted to understand better the math background of computation. I wanted to understand how Turing Machines worked, why all NP complete problems were reducible to each other, and what Godel's Incompleteness theorem meant.
#
# In these three goals I have achieved the first two and have a much better foundation to understand Gvdel's incompleteness theorem.
#
# I feel that in this semester I learned everything that I wanted to learn. On top of my goals I also learned how I could continue to learn and research computational theory as a profession.
